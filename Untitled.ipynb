# %%
import pandas as pd
import os

# %%
with open('consultaDespesa_Prefeitura_Teixeira_2024.csv', 'r', encoding='utf-8') as f:
    linhas = f.readlines()

# Contar o número de colunas na primeira linha
num_colunas = len(linhas[4].split(';'))  # Assume que a 4ª linha contém os dados
print(f"O arquivo possui {num_colunas} colunas na linha 5.")
# Out:
# O arquivo possui 29 colunas na linha 4.

# %%
colunas = linhas[10].split(';')
print(f"As colunas identificadas na linha 4 são:")
for i, coluna in enumerate(colunas):
    print(f"{i + 1}: {coluna}")
# Out:
# As colunas identificadas na linha 4 são:
# 1: DL
# 2: 41
# 3: 09/01/2024
# 4: MATUZALEM DE FIGUEIREDO RAMALHO
# 5: ***.364.415-**
# 6: NÃO
# 7:
# 8: VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO DE ALUGUEL DE UM IMOVEL PERTENCENTE A MATUZALEM FIGUEIREDO RAMALHO, ALUGADO A BENEFICIARIA PATRICIA DOS SANTOS GUEDES, QUE ENCONTRA-SE EM SITUAÇÃO DE VUNERABILIDADE SOCIAL.
# 9: 15001000 - Recursos Livres (Ordinário)
# 10: 0 - Ordinário
# 11: 2 - Prefeitura Municipal de Teixeira
# 12: 2120 - Fundo Municipal de Ação e Promoção Social
# 13: 8 - Assistência Social
# 14: 244 - Assistência Comunitária
# 15: 1002 - Promoção social à família, à criança, aos adolescentes e à população idosa
# 16: 2047 - Manutenção de  Benefícios  Eventuais
# 17: 3 - Despesas Correntes
# 18: 3 - Outras Despesas Correntes
# 19: 90 - Aplicações Diretas
# 20: 32 - Material, Bem Ou Serviço Para Distribuição Gratuita
# 21: 80.000,00
# 22: 150,00
# 23: 150,00
# 24: 150,00
# 25:
# 26: 0,00
# 27: 09/01/2024
# 28: 09/01/2024
# 29:

# %%
df24 = pd.read_csv('consultaDespesa_Prefeitura_Teixeira_2024.csv', sep=';', encoding='latin1',)

# %%
df24 = df24.drop(df.columns[[28, 29, 30, 31]], axis=1)

# %%
df24
# Out:
#      Unnamed: 0                                           NÃºmero  \
# 0           NaN   InstituiÃ§Ã£o: Prefeitura Municipal de Teixeira
# 1            DL                                                 4
# 2            DL                                                 7
# 3            DL                                                 8
# 4            DL                                                18
# ...         ...                                               ...
# 8678         DL                                              8725
# 8679         DL                                              8770
# 8680         DL                                              8771
# 8681         DL                                              8821
# 8682        NaN                    Total Fixado: 2.479.776.210,68
#
#                                 Data                                    Nome  \
# 0                                NaN                                     NaN
# 1                         02/01/2024                      BANCO DO BRASIL SA
# 2                         02/01/2024                 EMERSON LIMA DOS SANTOS
# 3                         02/01/2024                 JOSE ALEXANDRE DA SILVA
# 4                         04/01/2024                     JAIME GOMES MARTINS
# ...                              ...                                     ...
# 8678                      21/11/2024        Prefeitura Municipal de Teixeira
# 8679                      21/11/2024        Prefeitura Municipal de Teixeira
# 8680                      21/11/2024        Prefeitura Municipal de Teixeira
# 8681                      21/11/2024  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME
# 8682  Total Empenhado: 66.812.141,62          Total Liquidado: 66.748.473,39
#
#                        CPF/CNPJ          LicitaÃ§Ã£o          NÂº LicitaÃ§Ã£o  \
# 0                           NaN                  NaN                      NaN
# 1                ***.000.138-**                 NÃO                      NaN
# 2                ***.124.408-**                 NÃO                      NaN
# 3                ***.263.499-**                 NÃO                      NaN
# 4                ***.386.453-**                 NÃO                      NaN
# ...                         ...                  ...                      ...
# 8678             ***.395.000-**                 NÃO                      NaN
# 8679             ***.395.000-**                 NÃO                      NaN
# 8680             ***.395.000-**                 NÃO                      NaN
# 8681             ***.957.000-**                  SIM                000452023
# 8682  Total Pago: 65.939.511,28  Total Anulado: 0,00  Total Saldo: 872.630,34
#
#                                              HistÃ³rico  \
# 0                                                   NaN
# 1     VALO QUE SE EMPENHA PARA ATENDER AO PAGAMENTO,...
# 2     VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 3     VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 4     VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# ...                                                 ...
# 8678  VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 8679  VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 8680  VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 8681  VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 8682                                                NaN
#
#                                           Fonte Recurso      Modalidade  ...  \
# 0                                                   NaN             NaN  ...
# 1     16600000 - TransferÃªncia de Recursos do Fundo...  0 - OrdinÃ¡rio  ...
# 2               15001000 - Recursos Livres (OrdinÃ¡rio)  0 - OrdinÃ¡rio  ...
# 3               15001000 - Recursos Livres (OrdinÃ¡rio)  0 - OrdinÃ¡rio  ...
# 4               15001000 - Recursos Livres (OrdinÃ¡rio)  0 - OrdinÃ¡rio  ...
# ...                                                 ...             ...  ...
# 8678  15001002 - Recursos nÃ£o Vinculados de Imposto...  0 - OrdinÃ¡rio  ...
# 8679  15001002 - Recursos nÃ£o Vinculados de Imposto...  0 - OrdinÃ¡rio  ...
# 8680  15001002 - Recursos nÃ£o Vinculados de Imposto...  0 - OrdinÃ¡rio  ...
# 8681  15001002 - Recursos nÃ£o Vinculados de Imposto...  0 - OrdinÃ¡rio  ...
# 8682                                                NaN             NaN  ...
#
#                     AplicaÃ§Ã£o  \
# 0                           NaN
# 1     90 - AplicaÃ§Ãµes Diretas
# 2     90 - AplicaÃ§Ãµes Diretas
# 3     90 - AplicaÃ§Ãµes Diretas
# 4     90 - AplicaÃ§Ãµes Diretas
# ...                         ...
# 8678  90 - AplicaÃ§Ãµes Diretas
# 8679  90 - AplicaÃ§Ãµes Diretas
# 8680  90 - AplicaÃ§Ãµes Diretas
# 8681  90 - AplicaÃ§Ãµes Diretas
# 8682                        NaN
#
#                                                Elemento Valor Fixado  \
# 0                                                   NaN          NaN
# 1     39 - Outros ServiÃ§os De Terceiros - Pessoa Ju...     8.000,00
# 2     48 - Outros AuxÃ­lios Financeiros A Pessoas FÃ...   140.000,00
# 3     48 - Outros AuxÃ­lios Financeiros A Pessoas FÃ...   140.000,00
# 4     32 - Material, Bem Ou ServiÃ§o Para DistribuiÃ...    80.000,00
# ...                                                 ...          ...
# 8678  11 - Vencimentos E Vantagens Fixas - Pessoal C...   790.000,00
# 8679  11 - Vencimentos E Vantagens Fixas - Pessoal C...   790.000,00
# 8680           04 - ContrataÃ§Ã£o Por Tempo Determinado   260.000,00
# 8681                           30 - Material De Consumo    90.000,00
# 8682                                                NaN          NaN
#
#      Valor Empenhado Valor Liquidado Valor Pago Valor Anulado  Valor Saldo  \
# 0                NaN             NaN        NaN           NaN          NaN
# 1               5,70            5,70       5,70           NaN         0,00
# 2             150,00          150,00     150,00           NaN         0,00
# 3             300,00          300,00     300,00           NaN         0,00
# 4             150,00          150,00     150,00           NaN         0,00
# ...              ...             ...        ...           ...          ...
# 8678       41.798,80       41.798,80  41.798,80           NaN         0,00
# 8679       24.834,00       24.834,00  24.834,00           NaN         0,00
# 8680       36.028,20       36.028,20  36.028,20           NaN         0,00
# 8681        8.432,64        8.432,64       0,00           NaN     8.432,64
# 8682             NaN             NaN        NaN           NaN          NaN
#
#      Data de Pagamento  Data de LiquidaÃ§Ã£o
# 0                  NaN                   NaN
# 1           02/01/2024            02/01/2024
# 2           02/01/2024            02/01/2024
# 3           02/01/2024            02/01/2024
# 4           09/01/2024            09/01/2024
# ...                ...                   ...
# 8678        21/11/2024            21/11/2024
# 8679        21/11/2024            21/11/2024
# 8680        21/11/2024            21/11/2024
# 8681               NaN            21/11/2024
# 8682               NaN                   NaN
#
# [8683 rows x 28 columns]
