# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %% [markdown]
# ## 1. Tratamento e Limpeza de dados
#
# ##### Inicialmente, os dados estavam organizados por ano e apresentavam colunas extras em algumas linhas, o que exigiu a adição temporária de novas colunas ao arquivo para permitir a leitura correta dos dados. Após essa etapa, as colunas extras foram removidas. Também foi necessário eliminar linhas inconsistentes nos bancos de dados, como a primeira e a última de cada arquivo. Concluído esse tratamento, todos os arquivos foram concatenados em um único arquivo, visando simplificar as análises posteriores.

# %%
df24 = pd.read_csv('consultaDespesa_Prefeitura_Teixeira_2024.csv', sep=';')
df24 = df24.drop(df24.columns[[28, 29, 30, 31]], axis=1)
df24 = df24.drop([0, 8682], axis=0)

df23 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2023.csv', sep=';')
df23 = df23.drop(df23.columns[[28,29, 30, 31,32,33,34]], axis=1)
df23 = df23.drop([0, 9945], axis=0)

df22 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2022.csv', sep=';', )
df22 = df22.drop(df22.columns[[28,29, 30, 31]], axis=1)
df22 = df22.drop([0, 13102], axis=0)

df21 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2021.csv', sep=';')
df21 = df21.drop(df21.columns[[28,29, 30, 31]], axis=1)
df21 = df21.drop([0, 10744], axis=0)

df20 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2020.csv', sep=';')
df20 = df20.drop(df20.columns[[28,29, 30, 31]], axis=1)
df20 = df20.drop([0, 6378], axis=0)

df19 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2019.csv', sep=';')
df19 = df19.drop(df19.columns[[28,29, 30, 31]], axis=1)
df19 = df19.drop([0, 5719], axis=0)

df18= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2018.csv', sep=';', )
df18 = df18.drop(df18.columns[[28,29, 30, 31]], axis=1)
df18 = df18.drop([0, 5297], axis=0)

df17= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2017.csv', sep=';')
df17 = df17.drop(df17.columns[[28,29, 30, 31]], axis=1)
df17 = df17.drop([0, 6082], axis=0)

df16= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2016.csv', sep=';')
df16 = df16.drop(df16.columns[[28,29, 30, 31]], axis=1)
df16 = df16.drop([0, 8391], axis=0)

df15= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2015.csv', sep=';')
df15 = df15.drop(df15.columns[[28,29, 30, 31,32]], axis=1)
df15 = df15.drop([0, 6977], axis=0)

df14= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2014.csv', sep=';')
df14 = df14.drop(df14.columns[[28,29, 30, 31,32]], axis=1)
df14 = df14.drop([0, 5589], axis=0)

df = pd.concat([df24, df23, df22, df21, df20 ,df19 ,df18 ,df17 ,df16, df15,df14])

# %%
df2 = df.drop(["CPF/CNPJ", "Órgão", "Unnamed: 0", " Número", 
         "Natureza", "Nº Licitação", "Valor Anulado", "Data de Liquidação", 
         "Modalidade", "Subfunção", "Categoria Econômica", "Aplicação", "Elemento"], axis = 1)

# %%
df2['Valor Liquidado'] = (
    df2['Valor Liquidado']
    .str.replace('.', '', regex=False)   # Remove separadores de milhar
    .str.replace(',', '.', regex=False) 
    .pipe(pd.to_numeric, errors='coerce') # Converte para float, ignorando erros
)

df2['Valor Pago'] = (
    df2['Valor Pago']
    .str.replace('.', '', regex=False)   # Remove separadores de milhar
    .str.replace(',', '.', regex=False) 
    .pipe(pd.to_numeric, errors='coerce') # Converte para float, ignorando erros
)

df2['Valor Empenhado'] = (
    df2['Valor Empenhado']
    .str.replace('.', '', regex=False)   # Remove separadores de milhar
    .str.replace(',', '.', regex=False) 
    .pipe(pd.to_numeric, errors='coerce') # Converte para float, ignorando erros
)

# %%
df2.describe()
# Out:
#        Valor Empenhado  Valor Liquidado     Valor Pago
# count     86554.000000      86604.00000   86606.000000
# mean       5314.122143       5166.59852    4950.448529
# std       23117.696046      22277.19116   21807.525339
# min           0.000000          0.00000       0.000000
# 25%         200.000000        190.00000     150.000000
# 50%         954.000000        945.16500     866.285000
# 75%        2350.000000       2318.00000    2200.000000
# max      916884.410000     916884.41000  916884.410000

# %% [markdown]
# #### Verificando o valor maximo encontrado no dataframe

# %%
maximo = df2[(df2['Valor Liquidado'] > 900000)] 
maximo
# Out:
#             Data                                               Nome Licitação  \
# 6720  18/11/2021  SECRETARIA DE ESTADO DA EDUCACAO E DA CIENCIA ...       NÃO
#
#                                               Histórico  \
# 6720  VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
#
#                                           Fonte Recurso  \
# 6720  1111 - Exercício Corrente - Receitas de Impost...
#
#                           Unid. Orc         Função  \
# 6720  2080 - Secretaria de Educação  12 - Educação
#
#                                                Programa  \
# 6720  1027 - Programa de Revitalização do Ensino Fun...
#
#                                                    Ação Valor Fixado  \
# 6720  2033 - Manutenção das Atividades do  Ensino Fu...     5.613,00
#
#       Valor Empenhado  Valor Liquidado  Valor Pago  Valor Saldo  \
# 6720        916884.41        916884.41   916884.41         0,00
#
#      Data de Pagamento  Data de Liquidação
# 6720        18/11/2021          18/11/2021

# %%
print(maximo['Histórico'].iloc[0])
# Out:
# VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO REFERENTE DEVOLUÇÃO DE SALDO DE RECURSOS E RENDIMENTOS DE APLICAÇÕES FINANCEIRAS, NÃO UTILIZADOS NO CONVENIO 0352/2018 DA REFORMA DO SILVEIRA DANTAS DO PROJETO E PLANO DE TRABALHO APROVADO POR IMPOSSIBILIDADE DE EXECUÇÃO DO OBJETO POR DUPLICIDADE DE CONVENIOS COM O MESMO OBJETO PARA A MESMA ESCOLA. A OBRA FOI EXECUTADA COM RECURSOS DO CONVENIO SEEPB 0467/2019.

# %%
df2['Data'] = pd.to_datetime(df2['Data'], format='%d/%m/%Y', errors='coerce')
df2.dropna(subset=['Data'], inplace =True)                                                         #coloca os anos em inteiros
df2.loc[:, 'Ano'] = df2['Data'].dt.year.astype(int)

valores_por_ano = df2.groupby('Ano')[['Valor Liquidado', 'Valor Pago']].sum()

plt.figure(figsize=(10, 6))
valores_por_ano.plot(kind='bar', color=['skyblue', 'lightcoral'], edgecolor='black')
plt.title('Valores Liquidados por Ano', fontsize=16)
plt.xlabel('Ano', fontsize=14)
plt.ylabel('Valor Liquidado', fontsize=14)
plt.gca().yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))  #ajusta a escala do eixo y para milhões
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### A partir da análise do gráfico, observa-se um aumento significativo de 178,56% nos gastos da prefeitura ao longo dos últimos 10 anos. É fundamental investigar se esse aumento é resultado de maiores investimentos ou se decorre de um crescimento nas despesas das gestões mais recentes.

# %%
#cria uma nova coluna com o valor devedor do ano

valores_por_ano['Valor Devedor']  = valores_por_ano['Valor Liquidado'] - valores_por_ano['Valor Pago']      
valores_por_ano
# Out:
#       Valor Liquidado   Valor Pago  Valor Devedor
# Ano
# 2014      25183569.15  22112341.03     3071228.12
# 2015      23350616.25  23006579.01      344037.24
# 2016      30539437.30  29588338.11      951099.19
# 2017      28483712.06  27200222.35     1283489.71
# 2018      29525448.78  28214665.18     1310783.60
# 2019      29689225.21  29537918.33      151306.88
# 2020      39348355.85  39340062.95        8292.90
# 2021      45195205.14  43442007.03     1753198.11
# 2022      60885365.06  58555430.04     2329935.02
# 2023      65096019.36  61888094.04     3207925.32
# 2024      70151144.08  65852887.25     4298256.83

# %% [markdown]
# #### Devido à presença de múltiplos nomes na coluna "Função", que se referiam à mesma categoria, foi necessário estabelecer uma relação entre os diferentes nomes e suas respectivas áreas. Essa abordagem visa facilitar uma análise mais precisa e abrangente das áreas de investimento nos últimos 10 anos.

# %%
funcoes={
    '8 - Assistência Social' : 'social',
    '10 - Saúde' : 'saude',
    '2080 - Fundo Municipal de Saúde' : 'saude',
    '4 - Administração' : 'administracao',
    '2040 - Secretaria de Administração' : 'administracao',
    '20 - Agricultura' : 'agricultura',
    '2090 - Secretaria de Agricultura,Pecuária e Abastecimento' : 'agricultura',
    '13 - Cultura' : 'cultura',
    '12 - Educação' : 'educacao',
    '2150 - Secretaria de Educação' : 'educacao',
    '15 - Urbanismo' : 'urbanizacao',
    '2170 - Secretaria de Infraestrutura e Serviços Urbanos' : 'urbanizacao',
    '2050 - Secretaria de Saúde' : 'saude',
    '2090 - Fundo Municipal de Saúde' : 'saude',
    '2080 - Secretaria de Educação' : 'educacao',
    '2020 - Secretaria de Administração' : 'administracao',
    '2060 - Secretaria de Agricultura,Pecuária e Abastecimento' : 'agricultura',
    '2110 - Secretaria de Planejamento' : 'urbanizacao',
}

df2['categoria'] = df2['Função'].map(funcoes)

# %% [markdown]
# #### Por meio de um gráfico de linhas, é possível observar de maneira mais clara o crescimento dos investimentos em diversas áreas, permitindo uma comparação eficaz com o aumento das despesas.

# %%
df_categorias = df2.groupby(['Ano', 'categoria'])[['Valor Empenhado']].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=df_categorias, x='Ano', y='Valor Empenhado', hue='categoria', marker='o')


plt.title('Investimentos por Categoria')
plt.xlabel('Data')
plt.ylabel('Valor Empenhado')
plt.gca().yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))
plt.xticks(rotation=45)
plt.grid()
plt.legend(title='Categoria')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observa-se um expressivo crescimento nos valores destinados a diversas áreas, com destaque para a educação e saúde, que apresentaram os maiores orçamentos nos últimos anos. Além disso, é importante ressaltar o notável aumento de investimentos no setor agrícola do município, com um impressionante crescimento de 973% nos últimos 10 anos.

# %%
df_filtered = df_categorias[df_categorias['Ano'].isin([2014, 2024])]
df_pivot = df_filtered.pivot(index='categoria', columns='Ano', values='Valor Empenhado')
df_pivot['Aumento (%)'] = ((df_pivot[2024] - df_pivot[2014]) / df_pivot[2014]) * 100
df_pivot['Aumento (%)'] = df_pivot['Aumento (%)'].round(2)
df_pivot
# Out:
# Ano                   2014         2024  Aumento (%)
# categoria
# administracao   2828413.72   4059299.47        43.52
# agricultura      426505.48   4577201.25       973.19
# cultura          272365.50   1347692.14       394.81
# educacao       10094826.39  25504639.46       152.65
# saude           7386114.41  27023920.85       265.87
# social           717217.91   2414384.34       236.63
# urbanizacao     2757526.68   7600757.21       175.64

# %% [markdown]
# #### Analisar as Licitações ajuda a verificar os investimentos nos ultimos anos em obras, saúde, educação e segurança

# %%
df_licitacoes = df2[(df2['Licitação'] == 'SIM')]
df_licitacoes_agrupadas = df_licitacoes.groupby('Nome').agg(
    Valor_Liquidado=('Valor Liquidado', 'sum'),
    Anos=('Ano', lambda x: list(sorted(set(x))))  # remove duplicados e ordena os anos
).reset_index()

df_licitacoes_agrupadas = df_licitacoes_agrupadas.sort_values(by='Valor_Liquidado', ascending=False).reset_index(drop=True)
df_licitacoes_agrupadas.index = df_licitacoes_agrupadas.index + 1

# %%
df_licitacoes[df_licitacoes['Nome'] == 'POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME']
# Out:
#            Data                                    Nome Licitação  \
# 560  2024-03-22  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 563  2024-03-22  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 569  2024-03-22  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 670  2024-04-11  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 671  2024-04-11  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# ...         ...                                     ...       ...
# 3751 2016-09-06  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 3765 2016-10-06  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 3788 2016-11-09  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 3812 2016-12-27  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
# 3813 2016-12-07  POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME       SIM
#
#                                               Histórico  \
# 560   VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 563   VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 569   VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 670   VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 671   VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# ...                                                 ...
# 3751  DESPESA QUE SE EMPENHA PARA ATENDER AO PAGAMEN...
# 3765  DESPESA QUE SE EMPENHA PARA ATENDER AO PAGAMEN...
# 3788  DESPESA QUE SE EMPENHA PARA ATENDER AO PAGAMEN...
# 3812  DESPESA QUE SE EMPENHA PARA ATENDER AO PAGAMEN...
# 3813  DESPESA QUE SE EMPENHA PARA ATENDER AO PAGAMEN...
#
#                                           Fonte Recurso  \
# 560   16600000 - Transferência de Recursos do Fundo ...
# 563              15001000 - Recursos Livres (Ordinário)
# 569              15001000 - Recursos Livres (Ordinário)
# 670              15001000 - Recursos Livres (Ordinário)
# 671              15001000 - Recursos Livres (Ordinário)
# ...                                                 ...
# 3751                            0 - Recursos Ordinários
# 3765                            0 - Recursos Ordinários
# 3788                            0 - Recursos Ordinários
# 3812                            0 - Recursos Ordinários
# 3813                            0 - Recursos Ordinários
#
#                                               Unid. Orc  \
# 560    2120 - Fundo Municipal de Ação e Promoção Social
# 563    2120 - Fundo Municipal de Ação e Promoção Social
# 569    2120 - Fundo Municipal de Ação e Promoção Social
# 670    2120 - Fundo Municipal de Ação e Promoção Social
# 671    2120 - Fundo Municipal de Ação e Promoção Social
# ...                                                 ...
# 3751  2060 - Secretaria de Agricultura,Pecuária e Ab...
# 3765  2060 - Secretaria de Agricultura,Pecuária e Ab...
# 3788  2060 - Secretaria de Agricultura,Pecuária e Ab...
# 3812  2060 - Secretaria de Agricultura,Pecuária e Ab...
# 3813  2060 - Secretaria de Agricultura,Pecuária e Ab...
#
#                       Função  \
# 560   8 - Assistência Social
# 563   8 - Assistência Social
# 569   8 - Assistência Social
# 670   8 - Assistência Social
# 671   8 - Assistência Social
# ...                      ...
# 3751        20 - Agricultura
# 3765        20 - Agricultura
# 3788        20 - Agricultura
# 3812        20 - Agricultura
# 3813        20 - Agricultura
#
#                                                Programa  \
# 560   1002 - Promoção social à família, à criança, a...
# 563   1002 - Promoção social à família, à criança, a...
# 569   1002 - Promoção social à família, à criança, a...
# 670   1002 - Promoção social à família, à criança, a...
# 671   1002 - Promoção social à família, à criança, a...
# ...                                                 ...
# 3751  2015 - Programa de apoio administrativo da SECAPA
# 3765  2015 - Programa de apoio administrativo da SECAPA
# 3788  2015 - Programa de apoio administrativo da SECAPA
# 3812  2015 - Programa de apoio administrativo da SECAPA
# 3813  2015 - Programa de apoio administrativo da SECAPA
#
#                                                    Ação Valor Fixado  \
# 560   2046 - Programa Primeira Infância no SUAS - Cr...    10.000,00
# 563   2049 - Fundo Municipal de Assistência Social/F...    15.000,00
# 569   2049 - Fundo Municipal de Assistência Social/F...    15.000,00
# 670   2049 - Fundo Municipal de Assistência Social/F...    15.000,00
# 671   2049 - Fundo Municipal de Assistência Social/F...    15.000,00
# ...                                                 ...          ...
# 3751  2021 - Manutenção das Atividades Administrativ...   200.000,00
# 3765  2021 - Manutenção das Atividades Administrativ...   200.000,00
# 3788  2021 - Manutenção das Atividades Administrativ...   200.000,00
# 3812  2021 - Manutenção das Atividades Administrativ...   200.000,00
# 3813  2021 - Manutenção das Atividades Administrativ...   200.000,00
#
#       Valor Empenhado  Valor Liquidado  Valor Pago  Valor Saldo  \
# 560            746.61           746.61      746.61         0,00
# 563           2625.86          2625.86     2625.86         0,00
# 569           2167.09          2167.09     2167.09         0,00
# 670           5427.83          5427.83     5427.83         0,00
# 671           2194.78          2194.78     2194.78         0,00
# ...               ...              ...         ...          ...
# 3751         18962.91         18962.91    18962.91         0,00
# 3765         21745.16         21745.16    21745.16         0,00
# 3788         12476.17         12476.17    12476.17         0,00
# 3812         15208.23         15208.23        0.00    15.208,23
# 3813         18140.27         18140.27        0.00    18.140,27
#
#      Data de Pagamento  Data de Liquidação   Ano    categoria
# 560         22/03/2024          22/03/2024  2024       social
# 563         22/03/2024          22/03/2024  2024       social
# 569         22/03/2024          22/03/2024  2024       social
# 670         12/04/2024          11/04/2024  2024       social
# 671         12/04/2024          12/04/2024  2024       social
# ...                ...                 ...   ...          ...
# 3751        20/12/2016          06/09/2016  2016  agricultura
# 3765        20/12/2016          06/10/2016  2016  agricultura
# 3788        20/12/2016          09/11/2016  2016  agricultura
# 3812               NaN          27/12/2016  2016  agricultura
# 3813               NaN          07/12/2016  2016  agricultura
#
# [968 rows x 18 columns]

# %% [markdown]
# #### Chama a atenção que das 10 empresas que mais receberam de licitações do município , 5 aparentam ser do mesmo grupo, uma vez que todas terminam com EIRELI

# %%
df_licitacoes_agrupadas.head(10)
# Out:
#                                                  Nome  Valor_Liquidado  \
# 1              POSTO HW COMBUSTIVEIS COMERCIO LTDA-ME      12684730.37
# 2                       CONSTRUTORA J. GALDINO EIRELI       5956713.63
# 3   ARCO CONSTRUÇÕES CONSTRUTORA E SERVIÇOS EIRELI...       4667284.04
# 4   TORRE CONSTRUÇÃO E CONSULTORIA EM ENGENHARIA E...       3744187.26
# 5                               M & M CONSTRUCAO LTDA       3660487.70
# 6        COMERCIAL DE PRODUTOS ALIMENTICIOS JR EIRELI       3615780.86
# 7                  POSTO DE COMBUSTIVEL TEIXEIRA LTDA       2862968.63
# 8                          MELF CONSTRUTORA LTDA - ME       2525442.73
# 9                         ALEXANDRE PEREIRA DE FARIAS       2372037.06
# 10       E L F TEIXEIRA CONSTRUCOES E SERVICOS EIRELI       2196185.76
#
#                                                  Anos
# 1   [2016, 2017, 2018, 2019, 2020, 2021, 2022, 202...
# 2          [2016, 2017, 2019, 2020, 2021, 2022, 2023]
# 3                      [2014, 2015, 2016, 2019, 2020]
# 4                                  [2022, 2023, 2024]
# 5                            [2015, 2016, 2017, 2018]
# 6                            [2021, 2022, 2023, 2024]
# 7    [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2024]
# 8                                        [2017, 2018]
# 9                                  [2014, 2015, 2016]
# 10                           [2020, 2022, 2023, 2024]

# %%
print(df_licitacoes_agrupadas.iloc[1]['Nome'])
print(df_licitacoes_agrupadas.iloc[2]['Nome'])
print(df_licitacoes_agrupadas.iloc[3]['Nome'])
print(df_licitacoes_agrupadas.iloc[5]['Nome'])
print(df_licitacoes_agrupadas.iloc[9]['Nome'])
# Out:
# CONSTRUTORA J. GALDINO EIRELI
# ARCO CONSTRUÇÕES CONSTRUTORA E SERVIÇOS EIRELI - EPP  - EPP
# TORRE CONSTRUÇÃO E CONSULTORIA EM ENGENHARIA EIRELI
# COMERCIAL DE PRODUTOS ALIMENTICIOS JR EIRELI
# E L F TEIXEIRA CONSTRUCOES E SERVICOS EIRELI
