# %%
import pandas as pd
import os
import numpy

# %% [markdown]
# ## 1. Limpeza de dados
#
# ##### Inicialmente, os dados estavam organizados por ano e apresentavam colunas extras em algumas linhas, o que exigiu a adição temporária de novas colunas ao arquivo para permitir a leitura correta dos dados. Após essa etapa, as colunas extras foram removidas. Também foi necessário eliminar linhas inconsistentes nos bancos de dados, como a primeira e a última de cada arquivo. Concluído esse tratamento, todos os arquivos foram concatenados em um único arquivo, visando simplificar as análises posteriores.

# %%
df24 = pd.read_csv('consultaDespesa_Prefeitura_Teixeira_2024.csv', sep=';', encoding='latin1',)
df24 = df24.drop(df24.columns[[28, 29, 30, 31]], axis=1)
df24 = df24.drop([0, 8682], axis=0)

# %%
df23 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2023.csv', sep=';', encoding='latin1',)
df23 = df23.drop(df23.columns[[28,29, 30, 31,32,33,34]], axis=1)
df23 = df23.drop([0, 9945], axis=0)

# %%
df22 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2022.csv', sep=';', encoding='latin1',)
df22 = df22.drop(df22.columns[[28,29, 30, 31]], axis=1)
df22 = df22.drop([0, 13102], axis=0)

# %%
df21 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2021.csv', sep=';', encoding='latin1',)
df21 = df21.drop(df21.columns[[28,29, 30, 31]], axis=1)
df21 = df21.drop([0, 10744], axis=0)

# %%
df20 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2020.csv', sep=';', encoding='latin1',)
df20 = df20.drop(df20.columns[[28,29, 30, 31]], axis=1)
df20 = df20.drop([0, 6378], axis=0)

# %%
df19 = pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2019.csv', sep=';', encoding='latin1',)
df19 = df19.drop(df19.columns[[28,29, 30, 31]], axis=1)
df19 = df19.drop([0, 5719], axis=0)

# %%
df18= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2018.csv', sep=';', encoding='latin1',)
df18 = df18.drop(df18.columns[[28,29, 30, 31]], axis=1)
df18 = df18.drop([0, 5297], axis=0)

# %%
df17= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2017.csv', sep=';', encoding='latin1',)
df17 = df17.drop(df17.columns[[28,29, 30, 31]], axis=1)
df17 = df17.drop([0, 6082], axis=0)

# %%
df16= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2016.csv', sep=';', encoding='latin1',)
df16 = df16.drop(df16.columns[[28,29, 30, 31]], axis=1)
df16 = df16.drop([0, 8391], axis=0)

# %%
df15= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2015.csv', sep=';', encoding='latin1',)
df15 = df15.drop(df15.columns[[28,29, 30, 31,32]], axis=1)
df15 = df15.drop([0, 6977], axis=0)

# %%
df14= pd.read_csv('consultaDespesa_Prefeitura _Teixeira_2014.csv', sep=';', encoding='latin1',)
df14 = df14.drop(df14.columns[[28,29, 30, 31,32]], axis=1)
df14 = df14.drop([0, 5589], axis=0)

# %%
df = pd.concat([df24, df23, df22, df21, df20 ,df19 ,df18 ,df17 ,df16, df15,df14])

# %%
# Out:
#      Unnamed: 0  NÃºmero        Data                                  Nome  \
# 1            DL        4  02/01/2024                    BANCO DO BRASIL SA
# 2            DL        7  02/01/2024               EMERSON LIMA DOS SANTOS
# 3            DL        8  02/01/2024               JOSE ALEXANDRE DA SILVA
# 4            DL       18  04/01/2024                   JAIME GOMES MARTINS
# 5            DL       38  09/01/2024  ADRINA MARIA CONCEICAO SILVA FREITAS
# ...         ...      ...         ...                                   ...
# 5584         DL     4781  28/11/2014    FARMACIA SANTA MARIA MADALENA LTDA
# 5585         DL     5077  10/12/2014                 ANTONIO TIMOTEO GOMES
# 5586         DL     5266  24/12/2014    FARMACIA SANTA MARIA MADALENA LTDA
# 5587         DL     5269  26/12/2014    FARMACIA SANTA MARIA MADALENA LTDA
# 5588         DL     5301  30/12/2014    FARMACIA SANTA MARIA MADALENA LTDA
#
#             CPF/CNPJ LicitaÃ§Ã£o NÂº LicitaÃ§Ã£o  \
# 1     ***.000.138-**        NÃO             NaN
# 2     ***.124.408-**        NÃO             NaN
# 3     ***.263.499-**        NÃO             NaN
# 4     ***.386.453-**        NÃO             NaN
# 5     ***.893.474-**        NÃO             NaN
# ...              ...         ...             ...
# 5584  ***.599.000-**         SIM       000132014
# 5585  ***.540.453-**        NÃO             NaN
# 5586  ***.599.000-**         SIM       000132014
# 5587  ***.599.000-**         SIM       000132014
# 5588  ***.599.000-**         SIM       000132014
#
#                                              HistÃ³rico  \
# 1     VALO QUE SE EMPENHA PARA ATENDER AO PAGAMENTO,...
# 2     VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 3     VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 4     VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# 5     VALOR QUE SE EMPENHA PARA ATENDER AO PAGAMENTO...
# ...                                                 ...
# 5584  DESPESA QUE SE EMPENHA REFERENTE AO PAGAMENTO ...
# 5585  DESPESA QUE SE EMPENHA PARA ATENDER A AJUDA FI...
# 5586  DESPESA QUE SE EMPENHA REFERENTE AO PAGAMENTO ...
# 5587  DESPESA QUE SE EMPENHA REFERENTE AO PAGAMENTO ...
# 5588  DESPESA QUE SE EMPENHA REFERENTE AO PAGAMENTO ...
#
#                                           Fonte Recurso      Modalidade  ...  \
# 1     16600000 - TransferÃªncia de Recursos do Fundo...  0 - OrdinÃ¡rio  ...
# 2               15001000 - Recursos Livres (OrdinÃ¡rio)  0 - OrdinÃ¡rio  ...
# 3               15001000 - Recursos Livres (OrdinÃ¡rio)  0 - OrdinÃ¡rio  ...
# 4               15001000 - Recursos Livres (OrdinÃ¡rio)  0 - OrdinÃ¡rio  ...
# 5     16600000 - TransferÃªncia de Recursos do Fundo...  0 - OrdinÃ¡rio  ...
# ...                                                 ...             ...  ...
# 5584                                            8 - FUS      2 - Global  ...
# 5585                                            8 - FUS  0 - OrdinÃ¡rio  ...
# 5586                                            8 - FUS  0 - OrdinÃ¡rio  ...
# 5587                                            8 - FUS      2 - Global  ...
# 5588                                            8 - FUS  0 - OrdinÃ¡rio  ...
#
#                                                Elemento Valor Fixado  \
# 1     39 - Outros ServiÃ§os De Terceiros - Pessoa Ju...     8.000,00
# 2     48 - Outros AuxÃ­lios Financeiros A Pessoas FÃ...   140.000,00
# 3     48 - Outros AuxÃ­lios Financeiros A Pessoas FÃ...   140.000,00
# 4     32 - Material, Bem Ou ServiÃ§o Para DistribuiÃ...    80.000,00
# 5               92 - Despesas De ExercÃ­cios Anteriores     2.000,00
# ...                                                 ...          ...
# 5584           32 - Material de DistribuiÃ§Ã£o Gratuita       630,00
# 5585  48 - Outros AuxÃ­lios Financeiros a Pessoas FÃ...     4.424,00
# 5586           32 - Material de DistribuiÃ§Ã£o Gratuita       630,00
# 5587           32 - Material de DistribuiÃ§Ã£o Gratuita       630,00
# 5588           32 - Material de DistribuiÃ§Ã£o Gratuita       630,00
#
#      Valor Empenhado Valor Liquidado Valor Pago Valor Anulado  Valor Saldo  \
# 1               5,70            5,70       5,70           NaN         0,00
# 2             150,00          150,00     150,00           NaN         0,00
# 3             300,00          300,00     300,00           NaN         0,00
# 4             150,00          150,00     150,00           NaN         0,00
# 5           3.500,00        3.500,00   3.500,00           NaN         0,00
# ...              ...             ...        ...           ...          ...
# 5584        6.528,75        6.528,75       0,00           NaN     6.528,75
# 5585          300,00          300,00     300,00           NaN         0,00
# 5586       11.397,20       11.397,20       0,00           NaN    11.397,20
# 5587        7.022,32        7.022,32       0,00           NaN     7.022,32
# 5588        2.512,81        2.512,81       0,00           NaN     2.512,81
#
#      Data de Pagamento  Data de LiquidaÃ§Ã£o Data de LiquidaÃ§Ã£o
# 1           02/01/2024            02/01/2024                  NaN
# 2           02/01/2024            02/01/2024                  NaN
# 3           02/01/2024            02/01/2024                  NaN
# 4           09/01/2024            09/01/2024                  NaN
# 5           09/01/2024            09/01/2024                  NaN
# ...                ...                   ...                  ...
# 5584               NaN            28/11/2014                  NaN
# 5585        10/12/2014            10/12/2014                  NaN
# 5586               NaN            24/12/2014                  NaN
# 5587               NaN            26/12/2014                  NaN
# 5588               NaN            30/12/2014                  NaN
#
# [86895 rows x 29 columns]
